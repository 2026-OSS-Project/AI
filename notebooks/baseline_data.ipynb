# %%
# 1. Google Drive 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 2. 프로젝트 폴더 이동
# %cd /content/drive/MyDrive/OSS/AI
# Out:
# /content/drive/MyDrive/OSS/AI

# %%
from src.dataset import count_images

count_images("/content/drive/MyDrive/OSS/dataset/raw")
# Out:
# === 데이터셋 현황 ===
# can: 135장
# paper: 125장
# plastic: 114장
# vinyl: 128장
